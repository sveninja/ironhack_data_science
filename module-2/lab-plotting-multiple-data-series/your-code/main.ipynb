# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128355 entries, 0 to 128354
# Data columns (total 9 columns):
# Year               128355 non-null int64
# Month              128355 non-null int64
# Supplier           128331 non-null object
# ItemCode           128355 non-null object
# Description        128355 non-null object
# ItemType           128354 non-null object
# RetailSales        128355 non-null float64
# RetailTransfers    128355 non-null float64
# WarehouseSales     128355 non-null float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 8.8+ MB

# %%
data.describe()
# Out:
#                 Year          Month    RetailSales  RetailTransfers  \
# count  128355.000000  128355.000000  128355.000000    128355.000000
# mean     2017.206030       7.079303       6.563037         7.188161
# std         0.404454       3.645826      28.924944        30.640156
# min      2017.000000       1.000000      -6.490000       -27.660000
# 25%      2017.000000       5.000000       0.000000         0.000000
# 50%      2017.000000       8.000000       0.330000         0.000000
# 75%      2017.000000      10.000000       3.250000         4.000000
# max      2018.000000      12.000000    1616.600000      1587.990000
#
#        WarehouseSales
# count   128355.000000
# mean        22.624213
# std        239.693277
# min      -4996.000000
# 25%          0.000000
# 50%          1.000000
# 75%          4.000000
# max      16271.750000

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data_plot = data.groupby(["ItemType"]).agg("sum")[["RetailSales", "RetailTransfers", "WarehouseSales"]]
data_plot.plot.bar()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
len(data['Supplier'].unique())
# Out:
# 334

# %%
data_plot2 = data.groupby(['Supplier']).agg('sum')[['RetailSales']].sort_values(('RetailSales'))
# data_plot2 = data_plot2[0:9]
# data_plot2.plot(data_plot2, data[0:9])
data_plot2[-11:-1].plot.barh()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data_plot3 = data.groupby(["Month"]).agg("mean")[["RetailSales", "RetailTransfers", "WarehouseSales"]]
data_plot3.plot()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data_plot4 = data.groupby(["Month"]).agg("mean")[["RetailSales", "RetailTransfers", "WarehouseSales"]]
data_plot4.plot.bar()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
len(data['Year'].unique())
# Out:
# 2

# %%
data['Date'] = data.Year.astype(str) + '-' + data.Month.astype(str)
data
# Out:
#         Year  Month                              Supplier ItemCode  \
# 0       2017      4                       ROYAL WINE CORP   100200
# 1       2017      4              SANTA MARGHERITA USA INC   100749
# 2       2017      4                    JIM BEAM BRANDS CO    10103
# 3       2017      4          HEAVEN HILL DISTILLERIES INC    10120
# 4       2017      4                       ROYAL WINE CORP   101664
# 5       2017      4     REPUBLIC NATIONAL DISTRIBUTING CO   101680
# 6       2017      4                       ROYAL WINE CORP   101753
# 7       2017      4                    JIM BEAM BRANDS CO    10197
# 8       2017      4             STE MICHELLE WINE ESTATES   101974
# 9       2017      4             MONSIEUR TOUTON SELECTION   102083
# 10      2017      4                    JIM BEAM BRANDS CO    10243
# 11      2017      4                 BACCHUS IMPORTERS LTD    10246
# 12      2017      4                               MHW LTD    10266
# ...

# %%
# data_plot5.pivot_table(values='RetailSales', index='Date', columns='Item',aggfunc=sum)
# data_plot5.plot()

data_plot5 = data.pivot_table(values='RetailSales', index=['Year', 'Month'], columns='ItemType',aggfunc='sum')
data_plot5.plot(figsize=(14,8))

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
data_plot6 = data.pivot_table(values='RetailSales', index=['Year', 'Month'], columns='ItemType',aggfunc='sum')
data_plot6.plot.bar(figsize=(14,8))

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
# data_plot4 = data.groupby(["Month"]).agg("mean")[["RetailSales", "RetailTransfers", "WarehouseSales"]]
# data_plot4.plot.bar()

# data_plot6 = data.groupby([])

x = data['RetailSales']
y = data['RetailTransfers']

data_plot6 = data.groupby(['ItemType'])

fig, data_plot6 = plt.subplots(figsize=(5, 5))
# ax.scatter(x, y, c='k', s=5*(x + y), cmap='RdPu')
data_plot6.scatter(x, y)

# %%
import matplotlib.cm as cm

x = data['RetailSales']
y = data['RetailTransfers']
z = data['ItemType']
plt.scatter(x,y, c=z, s=5, cmap=cm.hsv)
cbar= plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     173     try:
# --> 174         rgba = _colors_full_map.cache[c, alpha]
#     175     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('WINE', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4231             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4232                 colors = mcolors.to_rgba_array(c)
#    4233                 n_elem = colors.shape[0]
#
# ...

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*
